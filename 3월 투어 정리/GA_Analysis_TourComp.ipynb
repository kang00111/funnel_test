# %%
import pandas as pd
import os
from datetime import datetime

# %%
### 현재 작업 디렉토리를 가져오기
current_directory = os.getcwd()

### downloads 상대경로를 절대경로로 변환
relative_path_downloads = r'..\\..\\..\\Downloads'
download_path = os.path.join(current_directory, relative_path_downloads)

### "preprocessed" 상대경로를 절대경로로 변환
preprocessed_path = os.path.join(download_path, 'preprocessed')

### Check if the "preprocessed" folder exists
if os.path.exists(preprocessed_path):
    print(f"The 'preprocessed' folder already exists at: {preprocessed_path}")
else:
    # "preprocessed" 폴더 생성
    os.makedirs(preprocessed_path)

### ContentsList 상대경로를 절대경로로 변환
relative_path_contentslist = r'..\\..\\..\\OneDrive - 클리 주식회사\문서 - 클리주식회사\000_Routine_마이세컨플레이스\02. IT Platform&Data\01_콘텐츠성과측정\001_ContentsList.xlsx'
contentslist_path = os.path.join(current_directory, relative_path_contentslist)

### DailyRawdata
path_dailyrawdata = r'..\\..\\..\\OneDrive - 클리 주식회사\문서 - 클리주식회사\000_Routine_마이세컨플레이스\02. IT Platform&Data\01_콘텐츠성과측정\01_DailyRawdata'

### new_id 파일 경로 설정
mapping_file_path = os.path.join(path_dailyrawdata, 'id_mapping.csv')

### 01_콘텐츠성과측정 상대경로를 절대경로로 변환
relative_path_upper_path = r'..\\..\\..\\OneDrive - 클리 주식회사\문서 - 클리주식회사\000_Routine_마이세컨플레이스\02. IT Platform&Data\01_콘텐츠성과측정'
upper_path = os.path.join(current_directory, relative_path_upper_path)


### 02_ConvertedData 상대경로를 절대경로로 변환
relative_path_convert_path = r'..\\..\\..\\OneDrive - 클리 주식회사\문서 - 클리주식회사\000_Routine_마이세컨플레이스\02. IT Platform&Data\01_콘텐츠성과측정\02_ConvertedData'
convert_path = os.path.join(current_directory, relative_path_convert_path)



### 03_CombinedData 상대경로를 절대경로로 변환
relative_path_combine_path = r'..\\..\\..\\OneDrive - 클리 주식회사\문서 - 클리주식회사\000_Routine_마이세컨플레이스\02. IT Platform&Data\01_콘텐츠성과측정\03_CombinedData'
combine_path = os.path.join(current_directory, relative_path_combine_path)


### 04_RequestedData 상대경로를 절대경로로 변환
relative_path_request_path = r'..\\..\\..\\OneDrive - 클리 주식회사\문서 - 클리주식회사\000_Routine_마이세컨플레이스\02. IT Platform&Data\01_콘텐츠성과측정\04_RequestedData'
request_path = os.path.join(current_directory, relative_path_request_path)

### 05_AnalysisData 상대경로를 절대경로로 변환
relative_path_analysis_path = r'..\\..\\..\\OneDrive - 클리 주식회사\문서 - 클리주식회사\000_Routine_마이세컨플레이스\02. IT Platform&Data\01_콘텐츠성과측정\05_AnalysisData'
analysis_path = os.path.join(current_directory, relative_path_analysis_path)

### 004_Project-4\09_세일즈 프로세스 개선 상대경로를 절대경로로 변환
relative_path_sales_path = r'..\\..\\..\\OneDrive - 클리 주식회사\문서 - 클리주식회사\004_Project-4\09_세일즈 프로세스 개선'
sales_path = os.path.join(current_directory, relative_path_analysis_path)
# Out:
# The 'preprocessed' folder already exists at: c:\Users\ch.kang\Documents\GitHub\funnel_test\..\\..\\..\\Downloads\preprocessed

# %%
# 파일이 있는 디렉토리 경로
directory = r'C:\Users\ch.kang\OneDrive - 클리 주식회사\문서 - 클리주식회사\000_Routine_마이세컨플레이스\02. IT Platform&Data\01_콘텐츠성과측정\02_ConvertedData'

# 파일 목록을 가져오기
files = os.listdir(directory)

# 파일 목록에서 특정 날짜 범위에 해당하는 파일들을 선택
selected_files = []
start_date = '2024-01-15'
end_date = '2024-03-17'

for file in files:
    if file.endswith('.xlsx'):
        date_string = file.split('_')[1]  # 파일명에서 날짜 부분 추출
        if start_date <= date_string <= end_date:
            selected_files.append(os.path.join(directory, file))

# 선택된 파일들을 읽어서 DataFrame으로 합치기
dfs = []
for file in selected_files:
    df = pd.read_excel(file)
    dfs.append(df)

# DataFrame 합치기
combined_df = pd.concat(dfs, ignore_index=True)

# 결과 출력 또는 처리
print(combined_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 25
#      22     dfs.append(df)
#      24 # DataFrame 합치기
# ---> 25 combined_df = pd.concat(dfs, ignore_index=True)
#      27 # 결과 출력 또는 처리
#      28 print(combined_df)
#
# File c:\Users\ch.kang\lab\Lib\site-packages\pandas\core\reshape\concat.py:380, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     377 elif copy and using_copy_on_write():
#     378     copy = False
# --> 380 op = _Concatenator(
#     381     objs,
#     382     axis=axis,
#     383     ignore_index=ignore_index,
#     384     join=join,
#     385     keys=keys,
#     386     levels=levels,
#     387     names=names,
#     388     verify_integrity=verify_integrity,
#     389     copy=copy,
#     390     sort=sort,
#     391 )
#     393 return op.get_result()
#
# File c:\Users\ch.kang\lab\Lib\site-packages\pandas\core\reshape\concat.py:443, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     440 self.verify_integrity = verify_integrity
#     441 self.copy = copy
# --> 443 objs, keys = self._clean_keys_and_objs(objs, keys)
#     445 # figure out what our result ndim is going to be
#     446 ndims = self._get_ndims(objs)
#
# File c:\Users\ch.kang\lab\Lib\site-packages\pandas\core\reshape\concat.py:505, in _Concatenator._clean_keys_and_objs(self, objs, keys)
#     502     objs_list = list(objs)
#     504 if len(objs_list) == 0:
# --> 505     raise ValueError("No objects to concatenate")
#     507 if keys is None:
#     508     objs_list = list(com.not_none(*objs_list))
#
# ValueError: No objects to concatenate

# %% [markdown]
# # 날짜 필터

# %%
# 'date_info' 열을 datetime 객체로 변환
data['date_info'] = pd.to_datetime(data['date_info'], format='%Y%m%d')

# 지정된 날짜 범위 내 데이터 필터링
start_date = pd.Timestamp(2024, 2, 6) # 20일 -> 13일로 변환(tourcomplete는 엑셀에서 20240213)
end_date = pd.Timestamp(2024, 3, 17)
filtered_data = data[(data['date_info'] >= start_date) & (data['date_info'] <= end_date)]
len(filtered_data)
filtered_data.to_excel("rawdata_sy.xlsx")

# %%
filtered_data.columns
# Out:
# Index(['new_id', 'date_info', 'conversion_1', 'conversion_2', 'conversion_3',
#        'source', 'medium', 'campaign', 'content', 'keyword',
#        ...
#        '95', '96', '97', '98', '99', '100', '101', '102', '103', '104'],
#       dtype='object', length=114)

# %% [markdown]
# # 유입 분석

# %% [markdown]
# ## UTM vs Keyword

# %%
total_visits = len(filtered_data)

# 모든 열 중에서 하나라도 값이 있는 경우를 그룹 1로 정의
utm_count = len(filtered_data[(filtered_data[['source', 'medium', 'campaign', 'content']].notnull()).any(axis=1)])

# keyword 값이 있는 그룹 (그룹 2)
keyword_count = len(filtered_data[(filtered_data['keyword'].notnull()) & 
                                  (filtered_data['keyword'] != 'missing')])
top_keywords = filtered_data[filtered_data['keyword'].notnull() & (filtered_data['keyword'] != 'missing')].groupby('keyword')['new_id'].nunique().reset_index(name='unique_visitors').sort_values('unique_visitors', ascending=False).head(10)

# 그룹 1과 그룹 2를 제외한 나머지는 그룹 3으로 정의
etc_count = total_visits - utm_count - keyword_count

print("UTM 유입수:", utm_count)
print("검색 유입수:", keyword_count)
print("기타 유입수:", etc_count)
print("총 유입수:", total_visits)
# Out:
# UTM 유입수: 17387
# 검색 유입수: 678
# 기타 유입수: 339
# 총 유입수: 18404

# %% [markdown]
# ## First vs Revisit

# %%
total_visits = len(filtered_data)
print("A = B+C | 설정 기간 내 총유입수: ", total_visits )

num_duplicate_visits = filtered_data.duplicated(subset='new_id', keep=False).sum()
num_first_visits = total_visits - num_duplicate_visits
num_duplicate_visitor = filtered_data.duplicated(subset='new_id', keep='first').sum()
print("B| 설정 기간 내 첫방문: ", num_first_visits )
print("C| 설정 기간 내 재방문(복수): ", num_duplicate_visits )
print("|설정 기간 내 재방문자(고유): ", num_duplicate_visitor )
# Out:
# A = B+C | 설정 기간 내 총유입수:  18404
# B| 설정 기간 내 첫방문:  15422
# C| 설정 기간 내 재방문(복수):  2982
# |설정 기간 내 재방문자(고유):  1648

# %% [markdown]
# ## TOP KEYWORD

# %%
top_keywords
# Out:
#                               keyword  unique_visitors
# 0                      (not provided)              301
# 1                  120206410183050614              140
# 42                           마이세컨플레이스               91
# 47                            마이세컨하우스               10
# 39                                마세플                3
# 9                            가평 세컨하우스                2
# 43  마이세컨플레이스 site:mysecondplace.co.kr                2
# 13                          강화도 세컨하우스                2
# 56                             세컨 하우스                2
# 97                           클리 세컨하우스                2

# %% [markdown]
# ## UTM별 분석

# %% [markdown]
# ### UTM -> 홈페이지 방문

# %%
# 널값을 'unknown'으로 대체하여 그룹화하기
filtered_data_filled = filtered_data.fillna('unknown')

# 그룹 1: Medium (캠페인 단위)
group_1 = filtered_data_filled.groupby('medium')
group_1_count = group_1['new_id'].count()
group_1_duplicate_visits = group_1.apply(lambda x: x.duplicated(subset='new_id', keep=False).sum())
group_1_revisit_rate = group_1_duplicate_visits / group_1_count

group_1_summary = pd.DataFrame({
    'total_visitors': group_1_count,
    'revisits': group_1_duplicate_visits,
    'revisit_rate': group_1_revisit_rate
}).sort_values(by='total_visitors', ascending=False)

print("그룹 1 (Medium 단위):", group_1_summary['total_visitors'].sum()) 
print(group_1_summary.head(5))

# 그룹 2: source + medium (캠페인 + 매체)
filtered_data_filled['source_medium'] = (filtered_data_filled['source'].fillna('unknown') + 
                                         ' | ' + 
                                         filtered_data_filled['medium'].fillna('unknown'))
group_2 = filtered_data_filled.groupby('source_medium')
group_2_count = group_2['new_id'].count()
group_2_duplicate_visits = group_2.apply(lambda x: x.duplicated(subset='new_id', keep=False).sum())
group_2_revisit_rate = group_2_duplicate_visits / group_2_count

group_2_summary = pd.DataFrame({
    'total_visitors': group_2_count,
    'revisits': group_2_duplicate_visits,
    'revisit_rate': group_2_revisit_rate
}).sort_values(by='total_visitors', ascending=False)

print("\n그룹 2 (Source + Medium 단위):", group_2_summary['total_visitors'].sum())
print(group_2_summary.head(5))

# 그룹 3: All (캠페인 + 매체 + 소재)
filtered_data_filled['all'] = (filtered_data_filled['source'].fillna('unknown') + 
                               ' | ' + 
                               filtered_data_filled['medium'].fillna('unknown') + 
                               ' | ' + 
                               filtered_data_filled['campaign'].fillna('unknown') + 
                               ' | ' + 
                               filtered_data_filled['content'].fillna('unknown'))
group_3 = filtered_data_filled.groupby('all')
group_3_count = group_3['new_id'].count()
group_3_duplicate_visits = group_3.apply(lambda x: x.duplicated(subset='new_id', keep=False).sum())
group_3_revisit_rate = group_3_duplicate_visits / group_3_count

group_3_summary = pd.DataFrame({
    'total_visitors': group_3_count,
    'revisits': group_3_duplicate_visits,
    'revisit_rate': group_3_revisit_rate
}).sort_values(by='total_visitors', ascending=False)

print("\n그룹 3 (All 단위):", group_3_summary['total_visitors'].sum())
print(group_3_summary.head(5))
# Out:
# 그룹 1 (Medium 단위): 18404
#                 total_visitors  revisits  revisit_rate
# medium
# 03_tour_locial            8893       970      0.109075
# 03_tour                   5742       466      0.081156
# unknown                   1017       152      0.149459
# referral                   656        58      0.088415
# gj_0002                    653        45      0.068913
#
# 그룹 2 (Source + Medium 단위): 18404
#                        total_visitors  revisits  revisit_rate
# source_medium
# igad | 03_tour_locial            7872       883      0.112170
# igad | 03_tour                   4643       388      0.083567
# fbad | 03_tour                   1080        73      0.067593
# unknown | unknown                1017       152      0.149459
# fbad | 03_tour_locial            1001        78      0.077922
#
# 그룹 3 (All 단위): 18404
#                                                 total_visitors  revisits  \
# all
# igad | 03_tour_locial | 02 | Instagram_Feed               4031       258
# igad | 03_tour | 05 | Instagram_Feed                      2722        51
# igad | 03_tour_locial | 02 | Instagram_Explore            2434        89
# unknown | unknown | unknown | unknown                     1017       152
# igad | 03_tour_locial | 02 | Instagram_Reels               851        83
#
#                                                 revisit_rate
# all
# igad | 03_tour_locial | 02 | Instagram_Feed         0.064004
# igad | 03_tour | 05 | Instagram_Feed                0.018736
# igad | 03_tour_locial | 02 | Instagram_Explore      0.036565
# unknown | unknown | unknown | unknown               0.149459
# igad | 03_tour_locial | 02 | Instagram_Reels        0.097532
# C:\Users\ch.kang\AppData\Local\Temp\ipykernel_21864\3164601292.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group_1_duplicate_visits = group_1.apply(lambda x: x.duplicated(subset='new_id', keep=False).sum())
# C:\Users\ch.kang\AppData\Local\Temp\ipykernel_21864\3164601292.py:25: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group_2_duplicate_visits = group_2.apply(lambda x: x.duplicated(subset='new_id', keep=False).sum())
# C:\Users\ch.kang\AppData\Local\Temp\ipykernel_21864\3164601292.py:47: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   group_3_duplicate_visits = group_3.apply(lambda x: x.duplicated(subset='new_id', keep=False).sum())

# %% [markdown]
# ### UTM -> 랜딩페이지

# %%
landing_page_summary = filtered_data_filled.groupby(['source_medium', '1']).size().reset_index(name='landing_page_visitors')
landing_page_summary_sorted = landing_page_summary.sort_values(by='landing_page_visitors', ascending=False)

print(landing_page_summary_sorted.head(10))
# Out:
#             source_medium                                               1  \
# 82  igad | 03_tour_locial            https://mysecondplace.co.kr/nopenzip
# 78         igad | 03_tour            https://mysecondplace.co.kr/nopenzip
# 79         igad | 03_tour  https://mysecondplace.co.kr/pb_secondhouse_ads
# 23  fbad | 03_tour_locial            https://mysecondplace.co.kr/nopenzip
# 20         fbad | 03_tour            https://mysecondplace.co.kr/nopenzip
# 77         igad | 03_tour                 https://mysecondplace.co.kr/msp
# 83  igad | 03_tour_locial  https://mysecondplace.co.kr/pb_secondhouse_ads
# 88      igreels | gj_0002         https://mysecondplace.co.kr/gongju_msp2
# 21         fbad | 03_tour  https://mysecondplace.co.kr/pb_secondhouse_ads
# 81  igad | 03_tour_locial                 https://mysecondplace.co.kr/msp
#
#     landing_page_visitors
# 82                   7061
# 78                   2288
# 79                   1705
# 23                    949
# 20                    690
# 77                    649
# 83                    572
# 88                    435
# 21                    292
# 81                    239

# %%
# # 그룹 1, 그룹 2, 그룹 3 결과를 하나의 데이터프레임으로 합치기
# group_results = pd.concat([group_1_summary, group_2_summary, group_3_summary], keys=['Group 1', 'Group 2', 'Group 3'])

# # 피벗 테이블 생성: total_visitors, revisits, revisit_rate
# pivot_table = group_results.pivot_table(index=group_results.index, 
#                                         values=['total_visitors', 'revisits', 'revisit_rate'], 
#                                         aggfunc={'total_visitors': 'sum', 'revisits': 'sum', 'revisit_rate': 'mean'})

# # 피벗 테이블을 데이터프레임으로 변환하여 결과 확인
# visit_df = pd.DataFrame(pivot_table.to_records())

# # 인덱스 열 이름 변경
# visit_df.rename(columns={'level_0': 'Group'}, inplace=True)
                   
# visit_df

# %% [markdown]
# # 투어 신청 전환 분석

# %% [markdown]
# ## 홈페이지 -> 투어신청페이지

# %%
tour_application_pattern = 'https://mysecondplace.co.kr/tour_application|https://mysecondplace.co.kr/secondhouse_blog/?bmode=view&idx=17967442|https://whattime.co.kr/msp_official/tour'
reached_tour_application = filtered_data.apply(lambda row: row.astype(str).str.contains(tour_application_pattern).any(), axis=1)
tour_application_users_count = reached_tour_application.sum()
print("투어신청페이지 방문수:", tour_application_users_count)
# Out:
# 투어신청페이지 방문수: 251

# %%
tour_complete_pattern = 'https://whattime.co.kr/m/reservation|https://mysecondplace.co.kr/tourcomplete|https://mysecondplace.co.kr/149'

# https://mysecondplace.co.kr/tourcomplete|https://whattime.co.kr/msp_official/tour|https://mysecondplace.co.kr/149
completed_tour_application = filtered_data.apply(lambda row: row.astype(str).str.contains(tour_complete_pattern).any(), axis=1)
tour_complete_users_count = completed_tour_application.sum()
tour_complete_users = filtered_data[completed_tour_application]['new_id']

print("투어신청완료 방문수:", tour_complete_users_count, "\n", tour_complete_users)
# Out:
# 투어신청완료 방문수: 19
#  3108     g-002873
# 3181     g-002967
# 5968     g-005544
# 11331    g-010205
# 13974    g-013594
# 15696    g-014597
# 18938    g-017803
# 19116    g-017660
# 19294    g-018139
# 19646    g-017286
# 19692    g-017278
# 19867    g-017524
# 19880    g-017541
# 20058    g-017339
# 20161    g-018317
# 20205    g-017404
# 20221    g-018348
# 20255    g-018368
# 20265    g-018358
# Name: new_id, dtype: object

# %%
tour_complete_pattern = 'https://whattime.co.kr/m/reservation|https://mysecondplace.co.kr/tourcomplete|https://mysecondplace.co.kr/149'

# 투어 완료 여부와 페이지 정보를 저장할 딕셔너리 초기화
tour_complete_info = {}

# 각 행을 탐색하면서 해당 행이 투어 완료 여부를 포함하는지 확인
for index, row in filtered_data.iterrows():
    is_tour_complete = row.astype(str).str.contains(tour_complete_pattern).any()
    if is_tour_complete:
        new_id = row['new_id']
        # 투어 완료한 사용자의 페이지 정보를 저장
        tour_complete_info[new_id] = row.to_dict()

# 투어 완료한 사용자의 수 출력
print("투어신청완료 방문수:", len(tour_complete_info))

# 각 사용자의 페이지 정보 출력
for new_id, page_info in tour_complete_info.items():
    print("new_id:", new_id)
    print("페이지 정보:", page_info)
# Out:
# 투어신청완료 방문수: 19
# new_id: g-002873
# 페이지 정보: {'new_id': 'g-002873', 'date_info': Timestamp('2024-02-12 00:00:00'), 'conversion_1': '투어신청', 'conversion_2': '0', 'conversion_3': '0', 'source': 'igreels', 'medium': 'gj_0002', 'campaign': '1', 'content': 'Instagram_Stories', 'keyword': '120206410183050614', '1': 'https://mysecondplace.co.kr/gongju_msp2', '2': 'https://mysecondplace.co.kr/tour_application', '3': 'https://mysecondplace.co.kr/tourcomplete', '4': 'https://mysecondplace.co.kr/secondhouse_market', '5': nan, '6': nan, '7': nan, '8': nan, '9': nan, '10': nan, '11': nan, '12': nan, '13': nan, '14': nan, '15': nan, '16': nan, '17': nan, '18': nan, '19': nan, '20': nan, '21': nan, '22': nan, '23': nan, '24': nan, '25': nan, '26': nan, '27': nan, '28': nan, '29': nan, '30': nan, '31': nan, '32': nan, '33': nan, '34': nan, '35': nan, '36': nan, '37': nan, '38': nan, '39': nan, '40': nan, '41': nan, '42': nan, '43': nan, '44': nan, '45': nan, '46': nan, '47': nan, '48': nan, '49': nan, '50': nan, '51': nan, '52': nan, '53': nan, '54': nan, '55': nan, '56': nan, '57': nan, '58': nan, '59': nan, '60': nan, '61': nan, '62': nan, '63': nan, '64': nan, '65': nan, '66': nan, '67': nan, '68': nan, '69': nan, '70': nan, '71': nan, '72': nan, '73': nan, '74': nan, '75': nan, '76': nan, '77': nan, '78': nan, '79': nan, '80': nan, '81': nan, '82': nan, '83': nan, '84': nan, '85': nan, '86': nan, '87': nan, '88': nan, '89': nan, '90': nan, '91': nan, '92': nan, '93': nan, '94': nan, '95': nan, '96': nan, '97': nan, '98': nan, '99': nan, '100': nan, '101': nan, '102': nan, '103': nan, '104': nan}
# new_id: g-002967
# 페이지 정보: {'new_id': 'g-002967', 'date_info': Timestamp('2024-02-13 00:00:00'), 'conversion_1': '투어신청', 'conversion_2': '0', 'conversion_3': '0', 'source': nan, 'medium': nan, 'campaign': nan, 'content': nan, 'keyword': nan, '1': 'https://mysecondplace.co.kr/tourcomplete', '2': nan, '3': nan, '4': nan, '5': nan, '6': nan, '7': nan, '8': nan, '9': nan, '10': nan, '11': nan, '12': nan, '13': nan, '14': nan, '15': nan, '16': nan, '17': nan, '18': nan, '19': nan, '20': nan, '21': nan, '22': nan, '23': nan, '24': nan, '25': nan, '26': nan, '27': nan, '28': nan, '29': nan, '30': nan, '31': nan, '32': nan, '33': nan, '34': nan, '35': nan, '36': nan, '37': nan, '38': nan, '39': nan, '40': nan, '41': nan, '42': nan, '43': nan, '44': nan, '45': nan, '46': nan, '47': nan, '48': nan, '49': nan, '50': nan, '51': nan, '52': nan, '53': nan, '54': nan, '55': nan, '56': nan, '57': nan, '58': nan, '59': nan, '60': nan, '61': nan, '62': nan, '63': nan, '64': nan, '65': nan, '66': nan, '67': nan, '68': nan, '69': nan, '70': nan, '71': nan, '72': nan, '73': nan, '74': nan, '75': nan, '76': nan, '77': nan, '78': nan, '79': nan, '80': nan, '81': nan, '82': nan, '83': nan, '84': nan, '85': nan, '86': nan, '87': nan, '88': nan, '89': nan, '90': nan, '91': nan, '92': nan, '93': nan, '94': nan, '95': nan, '96': nan, '97': nan, '98': nan, '99': nan, '100': nan, '101': nan, '102': nan, '103': nan, '104': nan}
# new_id: g-005544
# 페이지 정보: {'new_id': 'g-005544', 'date_info': Timestamp('2024-03-03 00:00:00'), 'conversion_1': nan, 'conversion_2': nan, 'conversion_3': nan, 'source': 'linktr.ee', 'medium': 'referral', 'campaign': '(referral)', 'content': nan, 'keyword': nan, '1': 'https://mysecondplace.co.kr/tour_application', '2': 'https://mysecondplace.co.kr/149', '3': 'https://mysecondplace.co.kr/secondhouse_market', '4': 'https://mysecondplace.co.kr/ya0008', '5': 'https://mysecondplace.co.kr/secondhouse_market', '6': 'https://mysecondplace.co.kr/market_gongju', '7': 'https://mysecondplace.co.kr/gongju_msp1', '8': 'https://mysecondplace.co.kr/market_gongju', '9': 'https://mysecondplace.co.kr/gongju_msp2', '10': 'https://mysecondplace.co.kr/pb_secondhouse_ads', '11': 'https://mysecondplace.co.kr/gongju_msp2', '12': 'https://mysecondplace.co.kr/secondhouse_service', '13': 'https://mysecondplace.co.kr/secondhouse_service/?idx=33', '14': 'https://mysecondplace.co.kr/secondhouse_service', '15': 'https://mysecondplace.co.kr/secondhouse_service/?idx=31', '16': 'https://mysecondplace.co.kr/shop_view/?idx=36', '17': nan, '18': nan, '19': nan, '20': nan, '21': nan, '22': nan, '23': nan, '24': nan, '25': nan, '26': nan, '27': nan, '28': nan, '29': nan, '30': nan, '31': nan, '32': nan, '33': nan, '34': nan, '35': nan, '36': nan, '37': nan, '38': nan, '39': nan, '40': nan, '41': nan, '42': nan, '43': nan, '44': nan, '45': nan, '46': nan, '47': nan, '48': nan, '49': nan, '50': nan, '51': nan, '52': nan, '53': nan, '54': nan, '55': nan, '56': nan, '57': nan, '58': nan, '59': nan, '60': nan, '61': nan, '62': nan, '63': nan, '64': nan, '65': nan, '66': nan, '67': nan, '68': nan, '69': nan, '70': nan, '71': nan, '72': nan, '73': nan, '74': nan, '75': nan, '76': nan, '77': nan, '78': nan, '79': nan, '80': nan, '81': nan, '82': nan, '83': nan, '84': nan, '85': nan, '86': nan, '87': nan, '88': nan, '89': nan, '90': nan, '91': nan, '92': nan, '93': nan, '94': nan, '95': nan, '96': nan, '97': nan, '98': nan, '99': nan, '100': nan, '101': nan, '102': nan, '103': nan, '104': nan}
# new_id: g-010205
# 페이지 정보: {'new_id': 'g-010205', 'date_info': Timestamp('2024-03-08 00:00:00'), 'conversion_1': nan, 'conversion_2': nan, 'conversion_3': nan, 'source': nan, 'medium': nan, 'campaign': nan, 'content': nan, 'keyword': nan, '1': 'https://whattime.co.kr/m/reservation/no1STJRwKb', '2': nan, '3': nan, '4': nan, '5': nan, '6': nan, '7': nan, '8': nan, '9': nan, '10': nan, '11': nan, '12': nan, '13': nan, '14': nan, '15': nan, '16': nan, '17': nan, '18': nan, '19': nan, '20': nan, '21': nan, '22': nan, '23': nan, '24': nan, '25': nan, '26': nan, '27': nan, '28': nan, '29': nan, '30': nan, '31': nan, '32': nan, '33': nan, '34': nan, '35': nan, '36': nan, '37': nan, '38': nan, '39': nan, '40': nan, '41': nan, '42': nan, '43': nan, '44': nan, '45': nan, '46': nan, '47': nan, '48': nan, '49': nan, '50': nan, '51': nan, '52': nan, '53': nan, '54': nan, '55': nan, '56': nan, '57': nan, '58': nan, '59': nan, '60': nan, '61': nan, '62': nan, '63': nan, '64': nan, '65': nan, '66': nan, '67': nan, '68': nan, '69': nan, '70': nan, '71': nan, '72': nan, '73': nan, '74': nan, '75': nan, '76': nan, '77': nan, '78': nan, '79': nan, '80': nan, '81': nan, '82': nan, '83': nan, '84': nan, '85': nan, '86': nan, '87': nan, '88': nan, '89': nan, '90': nan, '91': nan, '92': nan, '93': nan, '94': nan, '95': nan, '96': nan, '97': nan, '98': nan, '99': nan, '100': nan, '101': nan, '102': nan, '103': nan, '104': nan}
# new_id: g-013594
# 페이지 정보: {'new_id': 'g-013594', 'date_info': Timestamp('2024-03-10 00:00:00'), 'conversion_1': nan, 'conversion_2': nan, 'conversion_3': nan, 'source': nan, 'medium': nan, 'campaign': nan, 'content': nan, 'keyword': nan, '1': 'https://whattime.co.kr/m/reservation/qZapK9piQS', '2': nan, '3': nan, '4': nan, '5': nan, '6': nan, '7': nan, '8': nan, '9': nan, '10': nan, '11': nan, '12': nan, '13': nan, '14': nan, '15': nan, '16': nan, '17': nan, '18': nan, '19': nan, '20': nan, '21': nan, '22': nan, '23': nan, '24': nan, '25': nan, '26': nan, '27': nan, '28': nan, '29': nan, '30': nan, '31': nan, '32': nan, '33': nan, '34': nan, '35': nan, '36': nan, '37': nan, '38': nan, '39': nan, '40': nan, '41': nan, '42': nan, '43': nan, '44': nan, '45': nan, '46': nan, '47': nan, '48': nan, '49': nan, '50': nan, '51': nan, '52': nan, '53': nan, '54': nan, '55': nan, '56': nan, '57': nan, '58': nan, '59': nan, '60': nan, '61': nan, '62': nan, '63': nan, '64': nan, '65': nan, '66': nan, '67': nan, '68': nan, '69': nan, '70': nan, '71': nan, '72': nan, '73': nan, '74': nan, '75': nan, '76': nan, '77': nan, '78': nan, '79': nan, '80': nan, '81': nan, '82': nan, '83': nan, '84': nan, '85': nan, '86': nan, '87': nan, '88': nan, '89': nan, '90': nan, '91': nan, '92': nan, '93': nan, '94': nan, '95': nan, '96': nan, '97': nan, '98': nan, '99': nan, '100': nan, '101': nan, '102': nan, '103': nan, '104': nan}
# new_id: g-014597
# 페이지 정보: {'new_id': 'g-014597', 'date_info': Timestamp('2024-03-11 00:00:00'), 'conversion_1': nan, 'conversion_2': nan, 'conversion_3': nan, 'source': 'm.search.naver.com', 'medium': 'referral', 'campaign': '(referral)', 'content': nan, 'keyword': nan, '1': 'https://mysecondplace.co.kr', '2': 'https://mysecondplace.co.kr/gongju_msp2', '3': 'https://mysecondplace.co.kr/tour_application', '4': 'https://mysecondplace.co.kr/149', '5': 'https://mysecondplace.co.kr/secondhouse_market', '6': 'https://mysecondplace.co.kr/market_gongju', '7': 'https://mysecondplace.co.kr/gongju_msp1', '8': 'https://mysecondplace.co.kr/pb_secondhouse_ads', '9': 'https://mysecondplace.co.kr/gongju_msp2', '10': 'https://mysecondplace.co.kr/gongju_msp2', '11': 'https://mysecondplace.co.kr/market_gongju', '12': 'https://mysecondplace.co.kr/gongju_msp2', '13': nan, '14': nan, '15': nan, '16': nan, '17': nan, '18': nan, '19': nan, '20': nan, '21': nan, '22': nan, '23': nan, '24': nan, '25': nan, '26': nan, '27': nan, '28': nan, '29': nan, '30': nan, '31': nan, '32': nan, '33': nan, '34': nan, '35': nan, '36': nan, '37': nan, '38': nan, '39': nan, '40': nan, '41': nan, '42': nan, '43': nan, '44': nan, '45': nan, '46': nan, '47': nan, '48': nan, '49': nan, '50': nan, '51': nan, '52': nan, '53': nan, '54': nan, '55': nan, '56': nan, '57': nan, '58': nan, '59': nan, '60': nan, '61': nan, '62': nan, '63': nan, '64': nan, '65': nan, '66': nan, '67': nan, '68': nan, '69': nan, '70': nan, '71': nan, '72': nan, '73': nan, '74': nan, '75': nan, '76': nan, '77': nan, '78': nan, '79': nan, '80': nan, '81': nan, '82': nan, '83': nan, '84': nan, '85': nan, '86': nan, '87': nan, '88': nan, '89': nan, '90': nan, '91': nan, '92': nan, '93': nan, '94': nan, '95': nan, '96': nan, '97': nan, '98': nan, '99': nan, '100': nan, '101': nan, '102': nan, '103': nan, '104': nan}
# new_id: g-017803
# 페이지 정보: {'new_id': 'g-017803', 'date_info': Timestamp('2024-03-14 00:00:00'), 'conversion_1': nan, 'conversion_2': nan, 'conversion_3': nan, 'source': nan, 'medium': nan, 'campaign': nan, 'content': nan, 'keyword': nan, '1': 'https://whattime.co.kr/m/reservation/no1STJRwKb', '2': nan, '3': nan, '4': nan, '5': nan, '6': nan, '7': nan, '8': nan, '9': nan, '10': nan, '11': nan, '12': nan, '13': nan, '14': nan, '15': nan, '16': nan, '17': nan, '18': nan, '19': nan, '20': nan, '21': nan, '22': nan, '23': nan, '24': nan, '25': nan, '26': nan, '27': nan, '28': nan, '29': nan, '30': nan, '31': nan, '32': nan, '33': nan, '34': nan, '35': nan, '36': nan, '37': nan, '38': nan, '39': nan, '40': nan, '41': nan, '42': nan, '43': nan, '44': nan, '45': nan, '46': nan, '47': nan, '48': nan, '49': nan, '50': nan, '51': nan, '52': nan, '53': nan, '54': nan, '55': nan, '56': nan, '57': nan, '58': nan, '59': nan, '60': nan, '61': nan, '62': nan, '63': nan, '64': nan, '65': nan, '66': nan, '67': nan, '68': nan, '69': nan, '70': nan, '71': nan, '72': nan, '73': nan, '74': nan, '75': nan, '76': nan, '77': nan, '78': nan, '79': nan, '80': nan, '81': nan, '82': nan, '83': nan, '84': nan, '85': nan, '86': nan, '87': nan, '88': nan, '89': nan, '90': nan, '91': nan, '92': nan, '93': nan, '94': nan, '95': nan, '96': nan, '97': nan, '98': nan, '99': nan, '100': nan, '101': nan, '102': nan, '103': nan, '104': nan}
# new_id: g-017660
# 페이지 정보: {'new_id': 'g-017660', 'date_info': Timestamp('2024-03-14 00:00:00'), 'conversion_1': nan, 'conversion_2': nan, 'conversion_3': nan, 'source': nan, 'medium': nan, 'campaign': nan, 'content': nan, 'keyword': nan, '1': 'https://whattime.co.kr/m/cancel/S6n1PUNtVc', '2': 'https://whattime.co.kr/m/reschedule/S6n1PUNtVc', '3': 'https://whattime.co.kr/m/reservation/S6n1PUNtVc', '4': nan, '5': nan, '6': nan, '7': nan, '8': nan, '9': nan, '10': nan, '11': nan, '12': nan, '13': nan, '14': nan, '15': nan, '16': nan, '17': nan, '18': nan, '19': nan, '20': nan, '21': nan, '22': nan, '23': nan, '24': nan, '25': nan, '26': nan, '27': nan, '28': nan, '29': nan, '30': nan, '31': nan, '32': nan, '33': nan, '34': nan, '35': nan, '36': nan, '37': nan, '38': nan, '39': nan, '40': nan, '41': nan, '42': nan, '43': nan, '44': nan, '45': nan, '46': nan, '47': nan, '48': nan, '49': nan, '50': nan, '51': nan, '52': nan, '53': nan, '54': nan, '55': nan, '56': nan, '57': nan, '58': nan, '59': nan, '60': nan, '61': nan, '62': nan, '63': nan, '64': nan, '65': nan, '66': nan, '67': nan, '68': nan, '69': nan, '70': nan, '71': nan, '72': nan, '73': nan, '74': nan, '75': nan, '76': nan, '77': nan, '78': nan, '79': nan, '80': nan, '81': nan, '82': nan, '83': nan, '84': nan, '85': nan, '86': nan, '87': nan, '88': nan, '89': nan, '90': nan, '91': nan, '92': nan, '93': nan, '94': nan, '95': nan, '96': nan, '97': nan, '98': nan, '99': nan, '100': nan, '101': nan, '102': nan, '103': nan, '104': nan}
# new_id: g-018139
# 페이지 정보: {'new_id': 'g-018139', 'date_info': Timestamp('2024-03-14 00:00:00'), 'conversion_1': nan, 'conversion_2': nan, 'conversion_3': nan, 'source': nan, 'medium': nan, 'campaign': nan, 'content': nan, 'keyword': nan, '1': 'https://whattime.co.kr/m/reservation/1MDqD2EvqB', '2': nan, '3': nan, '4': nan, '5': nan, '6': nan, '7': nan, '8': nan, '9': nan, '10': nan, '11': nan, '12': nan, '13': nan, '14': nan, '15': nan, '16': nan, '17': nan, '18': nan, '19': nan, '20': nan, '21': nan, '22': nan, '23': nan, '24': nan, '25': nan, '26': nan, '27': nan, '28': nan, '29': nan, '30': nan, '31': nan, '32': nan, '33': nan, '34': nan, '35': nan, '36': nan, '37': nan, '38': nan, '39': nan, '40': nan, '41': nan, '42': nan, '43': nan, '44': nan, '45': nan, '46': nan, '47': nan, '48': nan, '49': nan, '50': nan, '51': nan, '52': nan, '53': nan, '54': nan, '55': nan, '56': nan, '57': nan, '58': nan, '59': nan, '60': nan, '61': nan, '62': nan, '63': nan, '64': nan, '65': nan, '66': nan, '67': nan, '68': nan, '69': nan, '70': nan, '71': nan, '72': nan, '73': nan, '74': nan, '75': nan, '76': nan, '77': nan, '78': nan, '79': nan, '80': nan, '81': nan, '82': nan, '83': nan, '84': nan, '85': nan, '86': nan, '87': nan, '88': nan, '89': nan, '90': nan, '91': nan, '92': nan, '93': nan, '94': nan, '95': nan, '96': nan, '97': nan, '98': nan, '99': nan, '100': nan, '101': nan, '102': nan, '103': nan, '104': nan}
# new_id: g-017286
# 페이지 정보: {'new_id': 'g-017286', 'date_info': Timestamp('2024-03-14 00:00:00'), 'conversion_1': nan, 'conversion_2': nan, 'conversion_3': nan, 'source': nan, 'medium': nan, 'campaign': nan, 'content': nan, 'keyword': nan, '1': 'https://whattime.co.kr/m/reservation/pygtchEin5', '2': nan, '3': nan, '4': nan, '5': nan, '6': nan, '7': nan, '8': nan, '9': nan, '10': nan, '11': nan, '12': nan, '13': nan, '14': nan, '15': nan, '16': nan, '17': nan, '18': nan, '19': nan, '20': nan, '21': nan, '22': nan, '23': nan, '24': nan, '25': nan, '26': nan, '27': nan, '28': nan, '29': nan, '30': nan, '31': nan, '32': nan, '33': nan, '34': nan, '35': nan, '36': nan, '37': nan, '38': nan, '39': nan, '40': nan, '41': nan, '42': nan, '43': nan, '44': nan, '45': nan, '46': nan, '47': nan, '48': nan, '49': nan, '50': nan, '51': nan, '52': nan, '53': nan, '54': nan, '55': nan, '56': nan, '57': nan, '58': nan, '59': nan, '60': nan, '61': nan, '62': nan, '63': nan, '64': nan, '65': nan, '66': nan, '67': nan, '68': nan, '69': nan, '70': nan, '71': nan, '72': nan, '73': nan, '74': nan, '75': nan, '76': nan, '77': nan, '78': nan, '79': nan, '80': nan, '81': nan, '82': nan, '83': nan, '84': nan, '85': nan, '86': nan, '87': nan, '88': nan, '89': nan, '90': nan, '91': nan, '92': nan, '93': nan, '94': nan, '95': nan, '96': nan, '97': nan, '98': nan, '99': nan, '100': nan, '101': nan, '102': nan, '103': nan, '104': nan}
# new_id: g-017278
# 페이지 정보: {'new_id': 'g-017278', 'date_info': Timestamp('2024-03-14 00:00:00'), 'conversion_1': nan, 'conversion_2': nan, 'conversion_3': nan, 'source': nan, 'medium': nan, 'campaign': nan, 'content': nan, 'keyword': nan, '1': 'https://whattime.co.kr/m/reservation/kXyjCyXcfR', '2': nan, '3': nan, '4': nan, '5': nan, '6': nan, '7': nan, '8': nan, '9': nan, '10': nan, '11': nan, '12': nan, '13': nan, '14': nan, '15': nan, '16': nan, '17': nan, '18': nan, '19': nan, '20': nan, '21': nan, '22': nan, '23': nan, '24': nan, '25': nan, '26': nan, '27': nan, '28': nan, '29': nan, '30': nan, '31': nan, '32': nan, '33': nan, '34': nan, '35': nan, '36': nan, '37': nan, '38': nan, '39': nan, '40': nan, '41': nan, '42': nan, '43': nan, '44': nan, '45': nan, '46': nan, '47': nan, '48': nan, '49': nan, '50': nan, '51': nan, '52': nan, '53': nan, '54': nan, '55': nan, '56': nan, '57': nan, '58': nan, '59': nan, '60': nan, '61': nan, '62': nan, '63': nan, '64': nan, '65': nan, '66': nan, '67': nan, '68': nan, '69': nan, '70': nan, '71': nan, '72': nan, '73': nan, '74': nan, '75': nan, '76': nan, '77': nan, '78': nan, '79': nan, '80': nan, '81': nan, '82': nan, '83': nan, '84': nan, '85': nan, '86': nan, '87': nan, '88': nan, '89': nan, '90': nan, '91': nan, '92': nan, '93': nan, '94': nan, '95': nan, '96': nan, '97': nan, '98': nan, '99': nan, '100': nan, '101': nan, '102': nan, '103': nan, '104': nan}
# new_id: g-017524
# 페이지 정보: {'new_id': 'g-017524', 'date_info': Timestamp('2024-03-14 00:00:00'), 'conversion_1': nan, 'conversion_2': nan, 'conversion_3': nan, 'source': nan, 'medium': nan, 'campaign': nan, 'content': nan, 'keyword': nan, '1': 'https://whattime.co.kr/m/reservation/1MDqD2EvqB', '2': nan, '3': nan, '4': nan, '5': nan, '6': nan, '7': nan, '8': nan, '9': nan, '10': nan, '11': nan, '12': nan, '13': nan, '14': nan, '15': nan, '16': nan, '17': nan, '18': nan, '19': nan, '20': nan, '21': nan, '22': nan, '23': nan, '24': nan, '25': nan, '26': nan, '27': nan, '28': nan, '29': nan, '30': nan, '31': nan, '32': nan, '33': nan, '34': nan, '35': nan, '36': nan, '37': nan, '38': nan, '39': nan, '40': nan, '41': nan, '42': nan, '43': nan, '44': nan, '45': nan, '46': nan, '47': nan, '48': nan, '49': nan, '50': nan, '51': nan, '52': nan, '53': nan, '54': nan, '55': nan, '56': nan, '57': nan, '58': nan, '59': nan, '60': nan, '61': nan, '62': nan, '63': nan, '64': nan, '65': nan, '66': nan, '67': nan, '68': nan, '69': nan, '70': nan, '71': nan, '72': nan, '73': nan, '74': nan, '75': nan, '76': nan, '77': nan, '78': nan, '79': nan, '80': nan, '81': nan, '82': nan, '83': nan, '84': nan, '85': nan, '86': nan, '87': nan, '88': nan, '89': nan, '90': nan, '91': nan, '92': nan, '93': nan, '94': nan, '95': nan, '96': nan, '97': nan, '98': nan, '99': nan, '100': nan, '101': nan, '102': nan, '103': nan, '104': nan}
# new_id: g-017541
# 페이지 정보: {'new_id': 'g-017541', 'date_info': Timestamp('2024-03-14 00:00:00'), 'conversion_1': nan, 'conversion_2': nan, 'conversion_3': nan, 'source': nan, 'medium': nan, 'campaign': nan, 'content': nan, 'keyword': nan, '1': 'https://whattime.co.kr/m/reservation/3xdpK8wext', '2': 'https://whattime.co.kr/m/reschedule/3xdpK8wext', '3': nan, '4': nan, '5': nan, '6': nan, '7': nan, '8': nan, '9': nan, '10': nan, '11': nan, '12': nan, '13': nan, '14': nan, '15': nan, '16': nan, '17': nan, '18': nan, '19': nan, '20': nan, '21': nan, '22': nan, '23': nan, '24': nan, '25': nan, '26': nan, '27': nan, '28': nan, '29': nan, '30': nan, '31': nan, '32': nan, '33': nan, '34': nan, '35': nan, '36': nan, '37': nan, '38': nan, '39': nan, '40': nan, '41': nan, '42': nan, '43': nan, '44': nan, '45': nan, '46': nan, '47': nan, '48': nan, '49': nan, '50': nan, '51': nan, '52': nan, '53': nan, '54': nan, '55': nan, '56': nan, '57': nan, '58': nan, '59': nan, '60': nan, '61': nan, '62': nan, '63': nan, '64': nan, '65': nan, '66': nan, '67': nan, '68': nan, '69': nan, '70': nan, '71': nan, '72': nan, '73': nan, '74': nan, '75': nan, '76': nan, '77': nan, '78': nan, '79': nan, '80': nan, '81': nan, '82': nan, '83': nan, '84': nan, '85': nan, '86': nan, '87': nan, '88': nan, '89': nan, '90': nan, '91': nan, '92': nan, '93': nan, '94': nan, '95': nan, '96': nan, '97': nan, '98': nan, '99': nan, '100': nan, '101': nan, '102': nan, '103': nan, '104': nan}
# new_id: g-017339
# 페이지 정보: {'new_id': 'g-017339', 'date_info': Timestamp('2024-03-14 00:00:00'), 'conversion_1': nan, 'conversion_2': nan, 'conversion_3': nan, 'source': nan, 'medium': nan, 'campaign': nan, 'content': nan, 'keyword': nan, '1': 'https://whattime.co.kr/m/reservation/8XgTTgYTSZ', '2': nan, '3': nan, '4': nan, '5': nan, '6': nan, '7': nan, '8': nan, '9': nan, '10': nan, '11': nan, '12': nan, '13': nan, '14': nan, '15': nan, '16': nan, '17': nan, '18': nan, '19': nan, '20': nan, '21': nan, '22': nan, '23': nan, '24': nan, '25': nan, '26': nan, '27': nan, '28': nan, '29': nan, '30': nan, '31': nan, '32': nan, '33': nan, '34': nan, '35': nan, '36': nan, '37': nan, '38': nan, '39': nan, '40': nan, '41': nan, '42': nan, '43': nan, '44': nan, '45': nan, '46': nan, '47': nan, '48': nan, '49': nan, '50': nan, '51': nan, '52': nan, '53': nan, '54': nan, '55': nan, '56': nan, '57': nan, '58': nan, '59': nan, '60': nan, '61': nan, '62': nan, '63': nan, '64': nan, '65': nan, '66': nan, '67': nan, '68': nan, '69': nan, '70': nan, '71': nan, '72': nan, '73': nan, '74': nan, '75': nan, '76': nan, '77': nan, '78': nan, '79': nan, '80': nan, '81': nan, '82': nan, '83': nan, '84': nan, '85': nan, '86': nan, '87': nan, '88': nan, '89': nan, '90': nan, '91': nan, '92': nan, '93': nan, '94': nan, '95': nan, '96': nan, '97': nan, '98': nan, '99': nan, '100': nan, '101': nan, '102': nan, '103': nan, '104': nan}
# new_id: g-018317
# 페이지 정보: {'new_id': 'g-018317', 'date_info': Timestamp('2024-03-15 00:00:00'), 'conversion_1': nan, 'conversion_2': nan, 'conversion_3': nan, 'source': nan, 'medium': nan, 'campaign': nan, 'content': nan, 'keyword': nan, '1': 'https://whattime.co.kr/m/reservation/BfbUrHV63o', '2': nan, '3': nan, '4': nan, '5': nan, '6': nan, '7': nan, '8': nan, '9': nan, '10': nan, '11': nan, '12': nan, '13': nan, '14': nan, '15': nan, '16': nan, '17': nan, '18': nan, '19': nan, '20': nan, '21': nan, '22': nan, '23': nan, '24': nan, '25': nan, '26': nan, '27': nan, '28': nan, '29': nan, '30': nan, '31': nan, '32': nan, '33': nan, '34': nan, '35': nan, '36': nan, '37': nan, '38': nan, '39': nan, '40': nan, '41': nan, '42': nan, '43': nan, '44': nan, '45': nan, '46': nan, '47': nan, '48': nan, '49': nan, '50': nan, '51': nan, '52': nan, '53': nan, '54': nan, '55': nan, '56': nan, '57': nan, '58': nan, '59': nan, '60': nan, '61': nan, '62': nan, '63': nan, '64': nan, '65': nan, '66': nan, '67': nan, '68': nan, '69': nan, '70': nan, '71': nan, '72': nan, '73': nan, '74': nan, '75': nan, '76': nan, '77': nan, '78': nan, '79': nan, '80': nan, '81': nan, '82': nan, '83': nan, '84': nan, '85': nan, '86': nan, '87': nan, '88': nan, '89': nan, '90': nan, '91': nan, '92': nan, '93': nan, '94': nan, '95': nan, '96': nan, '97': nan, '98': nan, '99': nan, '100': nan, '101': nan, '102': nan, '103': nan, '104': nan}
# new_id: g-017404
# 페이지 정보: {'new_id': 'g-017404', 'date_info': Timestamp('2024-03-15 00:00:00'), 'conversion_1': '투어신청', 'conversion_2': '투어신청', 'conversion_3': '0', 'source': nan, 'medium': nan, 'campaign': nan, 'content': nan, 'keyword': nan, '1': 'https://mysecondplace.co.kr/tour_application', '2': 'https://mysecondplace.co.kr/149', '3': 'https://mysecondplace.co.kr/secondhouse_market', '4': 'https://mysecondplace.co.kr/secondhouse_market', '5': 'https://mysecondplace.co.kr/gongju_msp1', '6': 'https://mysecondplace.co.kr/149', '7': 'https://mysecondplace.co.kr/tour_application', '8': 'https://mysecondplace.co.kr/secondhouse_market', '9': 'https://mysecondplace.co.kr/gongju_msp2', '10': 'https://mysecondplace.co.kr/secondhouse_market', '11': 'https://mysecondplace.co.kr/tour_application', '12': nan, '13': nan, '14': nan, '15': nan, '16': nan, '17': nan, '18': nan, '19': nan, '20': nan, '21': nan, '22': nan, '23': nan, '24': nan, '25': nan, '26': nan, '27': nan, '28': nan, '29': nan, '30': nan, '31': nan, '32': nan, '33': nan, '34': nan, '35': nan, '36': nan, '37': nan, '38': nan, '39': nan, '40': nan, '41': nan, '42': nan, '43': nan, '44': nan, '45': nan, '46': nan, '47': nan, '48': nan, '49': nan, '50': nan, '51': nan, '52': nan, '53': nan, '54': nan, '55': nan, '56': nan, '57': nan, '58': nan, '59': nan, '60': nan, '61': nan, '62': nan, '63': nan, '64': nan, '65': nan, '66': nan, '67': nan, '68': nan, '69': nan, '70': nan, '71': nan, '72': nan, '73': nan, '74': nan, '75': nan, '76': nan, '77': nan, '78': nan, '79': nan, '80': nan, '81': nan, '82': nan, '83': nan, '84': nan, '85': nan, '86': nan, '87': nan, '88': nan, '89': nan, '90': nan, '91': nan, '92': nan, '93': nan, '94': nan, '95': nan, '96': nan, '97': nan, '98': nan, '99': nan, '100': nan, '101': nan, '102': nan, '103': nan, '104': nan}
# new_id: g-018348
# 페이지 정보: {'new_id': 'g-018348', 'date_info': Timestamp('2024-03-16 00:00:00'), 'conversion_1': nan, 'conversion_2': nan, 'conversion_3': nan, 'source': nan, 'medium': nan, 'campaign': nan, 'content': nan, 'keyword': nan, '1': 'https://whattime.co.kr/m/reservation/2NcAztTBfx', '2': 'https://whattime.co.kr/m/reservation/2NcAztTBfx', '3': 'https://whattime.co.kr/m/reservation/2NcAztTBfx', '4': 'https://whattime.co.kr/m/reservation/2NcAztTBfx', '5': nan, '6': nan, '7': nan, '8': nan, '9': nan, '10': nan, '11': nan, '12': nan, '13': nan, '14': nan, '15': nan, '16': nan, '17': nan, '18': nan, '19': nan, '20': nan, '21': nan, '22': nan, '23': nan, '24': nan, '25': nan, '26': nan, '27': nan, '28': nan, '29': nan, '30': nan, '31': nan, '32': nan, '33': nan, '34': nan, '35': nan, '36': nan, '37': nan, '38': nan, '39': nan, '40': nan, '41': nan, '42': nan, '43': nan, '44': nan, '45': nan, '46': nan, '47': nan, '48': nan, '49': nan, '50': nan, '51': nan, '52': nan, '53': nan, '54': nan, '55': nan, '56': nan, '57': nan, '58': nan, '59': nan, '60': nan, '61': nan, '62': nan, '63': nan, '64': nan, '65': nan, '66': nan, '67': nan, '68': nan, '69': nan, '70': nan, '71': nan, '72': nan, '73': nan, '74': nan, '75': nan, '76': nan, '77': nan, '78': nan, '79': nan, '80': nan, '81': nan, '82': nan, '83': nan, '84': nan, '85': nan, '86': nan, '87': nan, '88': nan, '89': nan, '90': nan, '91': nan, '92': nan, '93': nan, '94': nan, '95': nan, '96': nan, '97': nan, '98': nan, '99': nan, '100': nan, '101': nan, '102': nan, '103': nan, '104': nan}
# new_id: g-018368
# 페이지 정보: {'new_id': 'g-018368', 'date_info': Timestamp('2024-03-17 00:00:00'), 'conversion_1': nan, 'conversion_2': nan, 'conversion_3': nan, 'source': nan, 'medium': nan, 'campaign': nan, 'content': nan, 'keyword': nan, '1': 'https://whattime.co.kr/m/reservation/UwjN6AhvmC', '2': nan, '3': nan, '4': nan, '5': nan, '6': nan, '7': nan, '8': nan, '9': nan, '10': nan, '11': nan, '12': nan, '13': nan, '14': nan, '15': nan, '16': nan, '17': nan, '18': nan, '19': nan, '20': nan, '21': nan, '22': nan, '23': nan, '24': nan, '25': nan, '26': nan, '27': nan, '28': nan, '29': nan, '30': nan, '31': nan, '32': nan, '33': nan, '34': nan, '35': nan, '36': nan, '37': nan, '38': nan, '39': nan, '40': nan, '41': nan, '42': nan, '43': nan, '44': nan, '45': nan, '46': nan, '47': nan, '48': nan, '49': nan, '50': nan, '51': nan, '52': nan, '53': nan, '54': nan, '55': nan, '56': nan, '57': nan, '58': nan, '59': nan, '60': nan, '61': nan, '62': nan, '63': nan, '64': nan, '65': nan, '66': nan, '67': nan, '68': nan, '69': nan, '70': nan, '71': nan, '72': nan, '73': nan, '74': nan, '75': nan, '76': nan, '77': nan, '78': nan, '79': nan, '80': nan, '81': nan, '82': nan, '83': nan, '84': nan, '85': nan, '86': nan, '87': nan, '88': nan, '89': nan, '90': nan, '91': nan, '92': nan, '93': nan, '94': nan, '95': nan, '96': nan, '97': nan, '98': nan, '99': nan, '100': nan, '101': nan, '102': nan, '103': nan, '104': nan}
# new_id: g-018358
# 페이지 정보: {'new_id': 'g-018358', 'date_info': Timestamp('2024-03-17 00:00:00'), 'conversion_1': nan, 'conversion_2': nan, 'conversion_3': nan, 'source': nan, 'medium': nan, 'campaign': nan, 'content': nan, 'keyword': nan, '1': 'https://whattime.co.kr/m/reservation/UwjN6AhvmC', '2': nan, '3': nan, '4': nan, '5': nan, '6': nan, '7': nan, '8': nan, '9': nan, '10': nan, '11': nan, '12': nan, '13': nan, '14': nan, '15': nan, '16': nan, '17': nan, '18': nan, '19': nan, '20': nan, '21': nan, '22': nan, '23': nan, '24': nan, '25': nan, '26': nan, '27': nan, '28': nan, '29': nan, '30': nan, '31': nan, '32': nan, '33': nan, '34': nan, '35': nan, '36': nan, '37': nan, '38': nan, '39': nan, '40': nan, '41': nan, '42': nan, '43': nan, '44': nan, '45': nan, '46': nan, '47': nan, '48': nan, '49': nan, '50': nan, '51': nan, '52': nan, '53': nan, '54': nan, '55': nan, '56': nan, '57': nan, '58': nan, '59': nan, '60': nan, '61': nan, '62': nan, '63': nan, '64': nan, '65': nan, '66': nan, '67': nan, '68': nan, '69': nan, '70': nan, '71': nan, '72': nan, '73': nan, '74': nan, '75': nan, '76': nan, '77': nan, '78': nan, '79': nan, '80': nan, '81': nan, '82': nan, '83': nan, '84': nan, '85': nan, '86': nan, '87': nan, '88': nan, '89': nan, '90': nan, '91': nan, '92': nan, '93': nan, '94': nan, '95': nan, '96': nan, '97': nan, '98': nan, '99': nan, '100': nan, '101': nan, '102': nan, '103': nan, '104': nan}

# %%
tour_application_users_ids = filtered_data[reached_tour_application]['new_id'].unique().tolist()
tour_application_users_ids
# Out:
# ['g-001897',
#  'g-001905',
#  'g-001839',
#  'g-001792',
#  'g-001809',
#  'g-001804',
#  'g-002036',
#  'g-002087',
#  'g-001959',
#  'g-001968',
#  'g-002126',
#  'g-002245',
#  'g-002378',
#  'g-002511',
#  'g-002867',
#  'g-002873',
#  'g-002986',
#  'g-003008',
#  'g-002980',
#  'g-003066',
#  'g-003098',
#  'g-003090',
#  'g-003128',
#  'g-003118',
#  'g-003163',
#  'g-003154',
#  'g-003263',
#  'g-003464',
#  'g-003525',
#  'g-003568',
#  'g-000102',
#  'g-004065',
#  'g-004062',
#  'g-004237',
#  'g-004523',
#  'g-004357',
#  'g-004401',
#  'g-004373',
#  'g-004473',
#  'g-004427',
#  'g-004973',
#  'g-004906',
#  'g-005081',
#  'g-005065',
#  'g-004986',
#  'g-005008',
#  'g-004764',
#  'g-004741',
#  'g-004860',
#  'g-004871',
#  'g-005248',
#  'g-005252',
#  'g-005340',
#  'g-005299',
#  'g-005303',
#  'g-005210',
#  'g-005214',
#  'g-005197',
#  'g-005180',
#  'g-005436',
#  'g-005437',
#  'g-005450',
#  'g-005432',
#  'g-005488',
#  'g-005524',
#  'g-005530',
#  'g-005544',
#  'g-005604',
#  'g-005886',
#  'g-005931',
#  'g-005829',
#  'g-005834',
#  'g-006106',
#  'g-006104',
#  'g-006123',
#  'g-006101',
#  'g-005723',
#  'g-004254',
#  'g-004365',
#  'g-006858',
#  'g-006805',
#  'g-006816',
#  'g-006619',
#  'g-006571',
#  'g-006741',
#  'g-006730',
#  'g-006766',
#  'g-006763',
#  'g-006666',
#  'g-006709',
#  'g-007324',
#  'g-007302',
#  'g-007297',
#  'g-007411',
#  'g-007111',
#  'g-007122',
#  'g-007023',
#  'g-007005',
#  'g-007204',
#  'g-007244',
#  'g-007221',
#  'g-007135',
#  'g-007161',
#  'g-006238',
#  'g-006308',
#  'g-006301',
#  'g-006284',
#  'g-005618',
#  'g-001670',
#  'g-006274',
#  'g-006443',
#  'g-006433',
#  'g-008141',
#  'g-008490',
#  'g-008510',
#  'g-007924',
#  'g-007824',
#  'g-007850',
#  'g-008041',
#  'g-007989',
#  'g-008637',
#  'g-008370',
#  'g-008213',
#  'g-008672',
#  'g-008673',
#  'g-008348',
#  'g-008779',
#  'g-008204',
#  'g-008709',
#  'g-008193',
#  'g-008198',
#  'g-007535',
#  'g-007603',
#  'g-001516',
#  'g-003393',
#  'g-007491',
#  'g-006400',
#  'g-006455',
#  'g-007749',
#  'g-007646',
#  'g-007658',
#  'g-009914',
#  'g-009867',
#  'g-009885',
#  'g-009896',
#  'g-009164',
#  'g-009052',
#  'g-009552',
#  'g-009398',
#  'g-009359',
#  'g-009793',
#  'g-009798',
#  'g-009773',
#  'g-008952',
#  'g-008817',
#  'g-008825',
#  'g-004953',
#  'g-003296',
#  'g-005667',
#  'g-008976',
#  'g-008944',
#  'g-009009',
#  'g-008872',
#  'g-010085',
#  'g-010146',
#  'g-010487',
#  'g-010012',
#  'g-010376',
#  'g-010339',
#  'g-010456',
#  'g-010415',
#  'g-010194',
#  'g-010314',
#  'g-010259',
#  'g-010774',
#  'g-010792',
#  'g-007378',
#  'g-010861',
#  'g-010691',
#  'g-011430',
#  'g-011941',
#  'g-012132',
#  'g-012122',
#  'g-011985',
#  'g-011485',
#  'g-010882',
#  'g-007902',
#  'g-012893',
#  'g-012627',
#  'g-012606',
#  'g-012760',
#  'g-013590',
#  'g-013616',
#  'g-013123',
#  'g-012537',
#  'g-012190',
#  'g-012167',
#  'g-014456',
#  'g-014117',
#  'g-014041',
#  'g-014197',
#  'g-014641',
#  'g-014597',
#  'g-014589',
#  'g-013721',
#  'g-013903',
#  'g-013959',
#  'g-013978',
#  'g-015544',
#  'g-015577',
#  'g-015677',
#  'g-015670',
#  'g-015654',
#  'g-015330',
#  'g-015486',
#  'g-016044',
#  'g-015935',
#  'g-015865',
#  'g-015018',
#  'g-014295',
#  'g-015189',
#  'g-015147',
#  'g-016595',
#  'g-016840',
#  'g-016844',
#  'g-017077',
#  'g-017121',
#  'g-016988',
#  'g-006879',
#  'g-016479',
#  'g-016420',
#  'g-017855',
#  'g-018233',
#  'g-018096',
#  'g-018039',
#  'g-018055',
#  'g-017210',
#  'g-001940',
#  'g-017381',
#  'g-017404',
#  'g-018292',
#  'g-018310',
#  'g-018300',
#  'g-018288']

# %% [markdown]
# # Depth

# %%
filtered_data_filled.columns
# Out:
# Index(['new_id', 'date_info', 'conversion_1', 'conversion_2', 'conversion_3',
#        'source', 'medium', 'campaign', 'content', 'keyword',
#        ...
#        '97', '98', '99', '100', '101', '102', '103', '104', 'source_medium',
#        'all'],
#       dtype='object', length=116)

# %%
# source_medium과 landing_page 기준으로 그룹화하여 방문 횟수를 계산합니다.
landing_page_visits = filtered_data_filled.groupby(['source_medium', '1']).size().reset_index(name='visits_landingpage')
# 'landing_page' 열의 이름을 '1'에서 'landing_page'로 변경합니다.
landing_page_visits.rename(columns={'1': 'landing_page'}, inplace=True)

# source_medium 별 총 방문 횟수를 계산합니다.
total_visits_by_source_medium = filtered_data_filled.groupby('source_medium').size().reset_index(name='visits_source_medium')

# 결과를 병합하여 source_medium 별 홈페이지 유입수와 랜딩페이지별 방문수를 가진 DataFrame을 생성합니다.
depth_df = pd.merge(landing_page_visits, total_visits_by_source_medium, on='source_medium')

# 병합한 데이터프레임을 'visits' 기준으로 내림차순 정렬합니다.
depth_df_sorted = depth_df.sort_values(by='visits_source_medium', ascending=False)

# %%
# 투어 완료 사용자들의 new_id 리스트 생성
tour_complete_users_ids = filtered_data_filled[completed_tour_application]['new_id'].unique().tolist()
# 모든 unique new_id를 가진 DataFrame 생성
all_new_ids = pd.Series(filtered_data_filled['new_id'].unique(), name='new_id').to_frame()

# 투어 신청 페이지 도달 여부와 투어 완료 여부를 나타내는 열 추가
all_new_ids['reached_tour_application'] = all_new_ids['new_id'].isin(tour_application_users_ids).astype(int)
all_new_ids['completed_tour_application'] = all_new_ids['new_id'].isin(tour_complete_users_ids).astype(int)

# 인덱스 재설정
all_new_ids.reset_index(drop=True, inplace=True)

# 필터링된 데이터프레임 생성
all_new_ids_filtered = all_new_ids[
    (all_new_ids['completed_tour_application'] == 1) | 
    (all_new_ids['reached_tour_application'] == 1)
]

# Step 1: new_id를 기준으로 source_medium, date, time 정보를 포함하는 매핑 데이터프레임 생성
new_id_to_info = filtered_data_filled[['new_id', 'date_info', 'source_medium', '1']].drop_duplicates()
# Step 2: all_new_ids_filtered 데이터프레임과 병합하여 source_medium, date, time 열 추가
all_new_ids_with_info = pd.merge(
    all_new_ids_filtered,
    new_id_to_info,
    on='new_id',
    how='left'
)
all_new_ids_with_complete_info = all_new_ids_with_info[['new_id', 'date_info', 'source_medium', '1', 'reached_tour_application', 'completed_tour_application']]
all_new_ids_with_complete_info.rename(columns={'1': 'landing_page'}, inplace=True)

# 결과 확인
all_new_ids_with_complete_info
# Out:
#        new_id  date_info                   source_medium  \
# 0    g-001897 2024-02-06            linktr.ee | referral
# 1    g-001905 2024-02-06            linktr.ee | referral
# 2    g-001905 2024-03-13            linktr.ee | referral
# 3    g-001839 2024-02-06            linktr.ee | referral
# 4    g-001792 2024-02-06            linktr.ee | referral
# ..        ...        ...                             ...
# 297  g-018300 2024-03-15  mysecondplace.co.kr | referral
# 298  g-018288 2024-03-15                naver | blog_msp
# 299  g-018348 2024-03-16               unknown | unknown
# 300  g-018368 2024-03-17               unknown | unknown
# 301  g-018358 2024-03-17               unknown | unknown
#
#                                           landing_page  \
# 0         https://mysecondplace.co.kr/tour_application
# 1                          https://mysecondplace.co.kr
# 2         https://mysecondplace.co.kr/tour_application
# 3    https://mysecondplace.co.kr/secondhouse_blog/?...
# 4    https://mysecondplace.co.kr/secondhouse_blog/?...
# ..                                                 ...
# 297           https://whattime.co.kr/msp_official/tour
# 298            https://mysecondplace.co.kr/gongju_msp2
# 299    https://whattime.co.kr/m/reservation/2NcAztTBfx
# 300    https://whattime.co.kr/m/reservation/UwjN6AhvmC
# 301    https://whattime.co.kr/m/reservation/UwjN6AhvmC
#
#      reached_tour_application  completed_tour_application
# 0                           1                           0
# 1                           1                           0
# 2                           1                           0
# 3                           1                           0
# 4                           1                           0
# ..                        ...                         ...
# 297                         1                           0
# 298                         1                           0
# 299                         0                           1
# 300                         0                           1
# 301                         0                           1
#
# [302 rows x 6 columns]

# %%
# depth_df_sorted와 all_new_ids_with_complete_info 데이터프레임을 조인하여 조인된 결과를 생성합니다.
merged_df = pd.merge(depth_df_sorted, all_new_ids_with_complete_info, on=['source_medium', 'landing_page'], how='left')

# 조인된 결과를 source_medium와 landing_page로 다시 그룹핑합니다.
grouped_merged_df = merged_df.groupby(['source_medium', 'landing_page']).agg({
    'total_visits_by_source_medium': 'sum',
    'landing_page_visits': 'sum',
    'reached_tour_application': 'sum',
    'completed_tour_application': 'sum'
}).reset_index()

# 열 순서를 조정합니다.
grouped_merged_df = grouped_merged_df[['source_medium', 'total_visits_by_source_medium', 'landing_page', 'landing_page_visits', 'reached_tour_application', 'completed_tour_application']]

# 'total_visits_by_source_medium' 및 'landing_page_visits' 열을 기준으로 내림차순 정렬합니다.
grouped_merged_df = grouped_merged_df.sort_values(by=['total_visits_by_source_medium', 'landing_page_visits'], ascending=False)
utm_df = grouped_merged_df
# 결과를 확인합니다.
print(utm_df)
# Out:
#                    source_medium  total_visits_by_source_medium  \
# 82         igad | 03_tour_locial                         259776
# 83         igad | 03_tour_locial                         110208
# 78                igad | 03_tour                          46430
# 79                igad | 03_tour                          32501
# 81         igad | 03_tour_locial                          23616
# ..                           ...                            ...
# 147         message | tour_visit                              1
# 148              msgad | 03_tour                              1
# 255      newsletter | main_title                              1
# 260  s7.spechorse.com | referral                              1
# 261   sadmin.imweb.me | referral                              1
#
#                                         landing_page  landing_page_visits  \
# 82              https://mysecondplace.co.kr/nopenzip               233013
# 83    https://mysecondplace.co.kr/pb_secondhouse_ads                 8008
# 78              https://mysecondplace.co.kr/nopenzip                22880
# 79    https://mysecondplace.co.kr/pb_secondhouse_ads                11935
# 81                   https://mysecondplace.co.kr/msp                  717
# ..                                               ...                  ...
# 147                      https://mysecondplace.co.kr                    1
# 148   https://mysecondplace.co.kr/pb_secondhouse_ads                    1
# 255                      https://mysecondplace.co.kr                    1
# 260  https://mysecondplace.co.kr/request_application                    1
# 261     https://mysecondplace.co.kr/secondhouse_blog                    1
#
#      reached_tour_application  completed_tour_application
# 82                       33.0                         0.0
# 83                       14.0                         0.0
# 78                       10.0                         0.0
# 79                        7.0                         0.0
# 81                        3.0                         0.0
# ..                        ...                         ...
# 147                       0.0                         0.0
# 148                       0.0                         0.0
# 255                       0.0                         0.0
# 260                       0.0                         0.0
# 261                       0.0                         0.0
#
# [396 rows x 6 columns]

# %%
unique_reached_values = utm_df['reached_tour_application'].unique()
unique_reached_values
# Out:
# array([ 33.,  14.,  10.,   7.,   3.,  15., 115.,   6.,   0.,   4.,  22.,
#          2.,   1.,   5.])

# %%
data = {
    "유입 유형": [ "총 유입", "UTM", "투어신청페이지", "투어신청완료", "검색", "기타", "첫방문", "재방문(복수)", "재방문자(고유)"],
    "수량": [total_visits, utm_count,tour_application_users_count, tour_complete_users_count, keyword_count, etc_count,  num_first_visits, num_duplicate_visits, num_duplicate_visitor]
}

# 데이터프레임 생성
analysis_df = pd.DataFrame(data)

# %%
# 날짜 범위를 문자열로 변환하여 파일 이름에 사용
start_date_str = start_date.strftime('%Y-%m-%d')
end_date_str = end_date.strftime('%Y-%m-%d')

# 파일 이름 생성
file_name = f'HomepageAnalysis_PaidMarketing_Tour_{start_date_str}to{end_date_str}.xlsx'
full_path = os.path.join(r'C:\Users\ch.kang\OneDrive - 클리 주식회사\문서 - 클리주식회사\004_Project-4\09_세일즈 프로세스 개선', file_name)

# ExcelWriter를 사용하여 Excel 파일로 내보내기
with pd.ExcelWriter(full_path, engine='xlsxwriter') as writer:
    analysis_df.to_excel(writer, sheet_name='InflowAnalysis', index=False)
    utm_df.to_excel(writer, sheet_name='Depth', index=False)
    all_new_ids_with_complete_info.to_excel(writer, sheet_name='new_id of conversion', index=False)
    top_keywords.to_excel(writer, sheet_name = 'Keyword', index=False)
print(f"File saved to {full_path}")
# Out:
# File saved to C:\Users\ch.kang\OneDrive - 클리 주식회사\문서 - 클리주식회사\004_Project-4\09_세일즈 프로세스 개선\HomepageAnalysis_PaidMarketing_Tour_2024-02-06to2024-03-17.xlsx
